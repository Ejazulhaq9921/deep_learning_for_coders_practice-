# %% [markdown]
# <a href="https://colab.research.google.com/github/Ejazulhaq9921/deep_learning_for_coders_practice-/blob/main/Is_it_a_bird%3F_Creating_a_model_from_your_own_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -Uqq fastai "duckduckgo_search>=6.2"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 14.9 MB/s eta 0:00:00
